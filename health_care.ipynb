# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("data_sets\healthcare_dataset.csv")

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df.tail()
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# 9995        2022-07-29       Samuel Moody   Wood, Martin and Simmons
# 9996        2022-01-06  Christopher Yates               Nash-Krueger
# 9997        2022-07-01   Robert Nicholson            Larson and Sons
# 9998        2020-02-06        Jamie Lewis               Wilson-Lyons
# 9999        2023-03-22        Tasha Avila  Torres, Young and Stewart
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df['Blood Type'].value_counts()
# Out:
# Blood Type
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    5075
# Male      4925
# Name: count, dtype: int64

# %%
df['Insurance Provider'].unique()
# Out:
# array(['Medicare', 'UnitedHealthcare', 'Aetna', 'Cigna', 'Blue Cross'],
#       dtype=object)

# %%
insurance=df[['Insurance Provider','Billing Amount']]

# %%
insurance
# Out:
#      Insurance Provider  Billing Amount
# 0              Medicare    37490.983364
# 1      UnitedHealthcare    47304.064845
# 2              Medicare    36874.896997
# 3              Medicare    23303.322092
# 4      UnitedHealthcare    18086.344184
# ...                 ...             ...
# 9995   UnitedHealthcare    39606.840083
# 9996         Blue Cross     5995.717488
# 9997         Blue Cross    49559.202905
# 9998   UnitedHealthcare    25236.344761
# 9999              Aetna    37223.965865
#
# [10000 rows x 2 columns]

# %%
df1=df[['Insurance Provider','Billing Amount']].groupby('Insurance Provider').sum()

# %%
df1
# Out:
#                     Billing Amount
# Insurance Provider
# Aetna                 5.232179e+07
# Blue Cross            5.212586e+07
# Cigna                 5.234017e+07
# Medicare              4.812977e+07
# UnitedHealthcare      5.025047e+07

# %%
df1.reset_index()
# Out:
#   Insurance Provider  Billing Amount
# 0              Aetna    5.232179e+07
# 1         Blue Cross    5.212586e+07
# 2              Cigna    5.234017e+07
# 3           Medicare    4.812977e+07
# 4   UnitedHealthcare    5.025047e+07

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='Insurance Provider'>

# %%
df['Hospital'].unique()
# Out:
# array(['Wallace-Hamilton', 'Burke, Griffin and Cooper', 'Walton LLC', ...,
#        'Nash-Krueger', 'Wilson-Lyons', 'Torres, Young and Stewart'],
#       dtype=object)

# %%
df2=df['Hospital'].value_counts()

# %%
df2
# Out:
# Hospital
# Smith PLC                        19
# Smith and Sons                   17
# Smith Ltd                        14
# Smith Inc                        14
# Johnson PLC                      13
#                                  ..
# Daniel-Benton                     1
# Franco, Hicks and Anderson        1
# Berry PLC                         1
# Martinez, Johnson and Carlson     1
# Torres, Young and Stewart         1
# Name: count, Length: 8639, dtype: int64

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df3=df['Gender'].value_counts()

# %%
df3
# Out:
# Gender
# Female    5075
# Male      4925
# Name: count, dtype: int64

# %%
df3.plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Insurance Provider'].value_counts()
# Out:
# Insurance Provider
# Cigna               2040
# Blue Cross          2032
# Aetna               2025
# UnitedHealthcare    1978
# Medicare            1925
# Name: count, dtype: int64

# %%
df['Hospital'].value_counts()
# Out:
# Hospital
# Smith PLC                        19
# Smith and Sons                   17
# Smith Ltd                        14
# Smith Inc                        14
# Johnson PLC                      13
#                                  ..
# Daniel-Benton                     1
# Franco, Hicks and Anderson        1
# Berry PLC                         1
# Martinez, Johnson and Carlson     1
# Torres, Young and Stewart         1
# Name: count, Length: 8639, dtype: int64

# %%
df4=df['Medical Condition'].value_counts()

# %%
df4
# Out:
# Medical Condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: count, dtype: int64

# %%
df4.plot(kind='bar')
# Out:
# <Axes: xlabel='Medical Condition'>

# %%
sns.catplot(data=df,x='Gender',y='Age',kind="box")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df5=df['Medication'].value_counts()

# %%
df5
# Out:
# Medication
# Penicillin     2079
# Lipitor        2015
# Ibuprofen      1976
# Aspirin        1968
# Paracetamol    1962
# Name: count, dtype: int64

# %%
df5.plot(kind='bar')
# Out:
# <Axes: xlabel='Medication'>

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df6=df['Test Results'].value_counts()

# %%
df6
# Out:
# Test Results
# Abnormal        3456
# Inconclusive    3277
# Normal          3267
# Name: count, dtype: int64
